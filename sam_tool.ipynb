# %%
# Install SAM and dependencies
# !pip install segment-anything opencv-python matplotlib supervision
# !pip install pycocotools  # For COCO format export

# For text-based selection (optional)
# !pip install ultralytics  # For YOLO-World integration
# Out:
# ...
#   Using cached supervision-0.26.1-py3-none-any.whl.metadata (13 kB)
# ...
#   Using cached scipy-1.16.1-cp311-cp311-macosx_14_0_arm64.whl.metadata (61 kB)
# ...
#   Using cached PyYAML-6.0.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (2.1 kB)
# ...
#   Using cached defusedxml-0.7.1-py2.py3-none-any.whl.metadata (32 kB)
# ...
#   Using cached requests-2.32.4-py3-none-any.whl.metadata (4.9 kB)
# ...
#   Using cached charset_normalizer-3.4.2-cp311-cp311-macosx_10_9_universal2.whl.metadata (35 kB)
# ...
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# ...
#   Using cached certifi-2025.8.3-py3-none-any.whl.metadata (2.4 kB)
# ...
# Using cached supervision-0.26.1-py3-none-any.whl (207 kB)
# Using cached defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Using cached PyYAML-6.0.2-cp311-cp311-macosx_11_0_arm64.whl (172 kB)
# Using cached requests-2.32.4-py3-none-any.whl (64 kB)
# ...

# %%
# !python samtool.py dataset/fan.jpg --mode interactive
# Out:
# Loading SAM vit_b model...
# Instructions:
# - Left click: Add positive point (object)
# - Right click: Add negative point (background)
# - 'r': Reset selection
# - 's': Save current mask
# - 'q': Quit
# Mask saved to fan_mask.png
# Saved 1 masks to sam_output

# %%
# For detection (bounding boxes only)
# !python sam_to_yolo.py sam_output "/Users/prudhvivuda/Documents/vaultlyai code/segmentation-and-labelling/dataset/fan.jpg" --output yolo_labels --format detection
# Out:
# Found masks for 1 images
# Converting to YOLO detection format...
# ...
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 25.38it/s]
#
# ✅ Conversion complete!
# 📁 Labels saved to: yolo_labels/labels
# 📄 Summary saved to: yolo_labels/conversion_summary.json
# 📝 Classes saved to: yolo_labels/classes.txt
#
# 📊 Sample YOLO label (from fan):
#    0 0.570382 0.594875 0.603464 0.413750

# %%
# !python samtool.py "dataset/instant pot.jpg" --mode interactive
# Out:
# Loading SAM vit_b model...
# Instructions:
# - Left click: Add positive point (object)
# - Right click: Add negative point (background)
# - 'r': Reset selection
# - 's': Save current mask
# - 'q': Quit
# Mask saved to instant pot_mask.png
# Saved 1 masks to sam_output

# %%
# For detection (bounding boxes only)
# !python sam_to_yolo.py sam_output "/Users/prudhvivuda/Documents/vaultlyai code/segmentation-and-labelling/dataset/instant pot.jpg" --output yolo_labels --format detection
# Out:
# Found masks for 2 images
# Converting to YOLO detection format...
#   0%|                                                     | 0/2 [00:00<?, ?it/s]✓ fan: 1 objects
# ✓ instant pot: 1 objects
# 100%|█████████████████████████████████████████████| 2/2 [00:00<00:00, 27.54it/s]
#
# ✅ Conversion complete!
# 📁 Labels saved to: yolo_labels/labels
# 📄 Summary saved to: yolo_labels/conversion_summary.json
# 📝 Classes saved to: yolo_labels/classes.txt
#
# 📊 Sample YOLO label (from fan):
#    0 0.570382 0.594875 0.603464 0.413750

# %%
# For segmentation (polygon masks)
# !python sam_to_yolo.py sam_output "/Users/prudhvivuda/Documents/vaultlyai code/segmentation-and-labelling/dataset/fan.jpg" --output yolo_labels --format segmentation
# Out:
# Found masks for 1 images
# Converting to YOLO segmentation format...
# ...
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 13.04it/s]
#
# ✅ Conversion complete!
# 📁 Labels saved to: yolo_labels/labels
# 📄 Summary saved to: yolo_labels/conversion_summary.json
# 📝 Classes saved to: yolo_labels/classes.txt
#
# 📊 Sample YOLO label (from fan):
#    0 0.402753 0.415250 0.339254 0.446500 0.303286 0.489500 0.293517 0.662500 0.269982 0.725000 0.313055 0.735000 0.431616 0.717500 0.546625 0.727500 0.661190 0.752000 0.681172 0.797000 0.775755 0.795500 0.872114 0.740500 0.864565 0.721000 0.841474 0.714750 0.846803 0.570750 0.804618 0.477000 0.729130 0.423500 0.621226 0.391750 0.544849 0.388250

# %%
# !python interactive_sam_folder.py dataset/ output/
# Out:
# Loading SAM vit_b model...
#
# ...
# Found 15 images to process interactively
# ...
#
#
# [1/15] Processing: bag.jpg
#
# ...
# INTERACTIVE SELECTION CONTROLS:
# --------------------------------------------------
# 🖱️  Left Click        : Add object point (green)
# 🖱️  Right Click       : Add background point (red)
# 🖱️  Ctrl+Drag        : Draw bounding box
# ⌨️  'a' / 'Enter'    : Accept current mask
# ⌨️  '1-9'            : Assign class to mask
# ⌨️  'r'              : Reset current selection
# ⌨️  'u'              : Undo last mask
# ⌨️  's'              : Skip this image
# ⌨️  'q' / 'ESC'      : Finish and save
# ...
#
#   ✓ Saved mask 1: object (area: 3917455)
#   ✓ Saved mask 2: object (area: 3947703)
# ✓ Saved 2 masks for bag.jpg
#
# [2/15] Processing: blender motor + air fryer + microwave.jpg
#
# ...
# INTERACTIVE SELECTION CONTROLS:
# --------------------------------------------------
# 🖱️  Left Click        : Add object point (green)
# 🖱️  Right Click       : Add background point (red)
# ...

# %%
# !python sam_to_yolo.py output/ dataset/ --output yolo_labels
# Out:
# Found masks for 7 images
# Converting to YOLO detection format...
#   0%|                                                     | 0/7 [00:00<?, ?it/s]✓ bag: 2 objects
# ✓ blender motor + air fryer: 1 objects
# ✓ blender motor + air fryer + microwave: 1 objects
#  43%|███████████████████▎                         | 3/7 [00:00<00:00, 25.23it/s]✓ dish washer: 1 objects
# ✓ dryer + washer: 1 objects
# ✓ fan: 1 objects
# ...
# 100%|█████████████████████████████████████████████| 7/7 [00:00<00:00, 22.24it/s]
#
# ✅ Conversion complete!
# 📁 Labels saved to: yolo_labels/labels
# 📄 Summary saved to: yolo_labels/conversion_summary.json
# 📝 Classes saved to: yolo_labels/classes.txt
#
# 📊 Sample YOLO label (from bag):
#    0 0.443000 0.502664 0.609000 0.946714
#    0 0.444000 0.510879 0.608000 0.965808

# %%
# !python interactive_sam_folder.py "dataset/blender motor + air fryer + microwave.jpg" output/
# Out:
# Loading SAM vit_b model...
# Processing single image: blender motor + air fryer + microwave.jpg
#
# ...
# INTERACTIVE SELECTION CONTROLS:
# --------------------------------------------------
# 🖱️  Left Click        : Add object point (green)
# 🖱️  Right Click       : Add background point (red)
# 🖱️  Ctrl+Drag        : Draw bounding box
# ⌨️  'a' / 'Enter'    : Accept and save current mask
# ⌨️  'r'              : Reset current selection
# ⌨️  'u'              : Undo last mask
# ⌨️  's'              : Skip this image
# ⌨️  'q' / 'ESC'      : Finish and go to next image
# ...
#
#   ✓ Saved mask 1 (area: 2212295)
#
# ✅ Saved 1 masks for blender motor + air fryer + microwave.jpg
# 📁 Output saved to: output

# %%
# !python unified_sam_tool.py "dataset/blender motor + air fryer + microwave.jpg" output/
# Out:
# Initializing Unified SAM Tool...
# Using device: mps
# Using cached checkpoint: /Users/prudhvivuda/.cache/sam/sam_vit_b_01ec64.pth
# Loading SAM vit_b model...
# ✓ Model loaded successfully
#
# ...
# Starting interactive selection for 1 image(s)
# ...
#
#
# [1/1] Processing: blender motor + air fryer + microwave.jpg
#
# ...
# INTERACTIVE SELECTION CONTROLS:
# --------------------------------------------------
# 🖱️  Left Click        : Add object point (green)
# 🖱️  Right Click       : Add background point (red)
# 🖱️  Ctrl+Drag        : Draw bounding box
# ⌨️  'a' / 'Enter'    : Accept and save current mask
# ⌨️  'r'              : Reset current selection
# ⌨️  'u'              : Undo last saved mask
# ⌨️  's'              : Skip this image
# ⌨️  'q' / 'ESC'      : Next image / Finish
# ...
#
#   ✓ Saved mask 1 (area: 261661 pixels)
#   ✓ Saved mask 2 (area: 833609 pixels)
#   ✓ Saved mask 3 (area: 1121718 pixels)
# ✓ Saved 3 masks
#
# ...
# ✅ Interactive selection complete!
# 📊 Total masks selected: 3
# ...

# %%
# !python sam_tool.py "dataset/blender motor + air fryer + microwave.jpg" output_new/ --mode interactive --device mps --export-yolo
# Out:
# Initializing SAM Tool...
# Using device: mps
# Using cached checkpoint: /Users/prudhvivuda/.cache/sam/sam_vit_b_01ec64.pth
# Loading SAM vit_b model...
# ✓ Model loaded successfully
#
# ...
# Starting interactive selection for 1 image(s)
# ...
#
#
# [1/1] Processing: blender motor + air fryer + microwave.jpg
#
# ...
# INTERACTIVE SELECTION CONTROLS:
# --------------------------------------------------
# 🖱️  Left Click        : Add object point (green)
# 🖱️  Right Click       : Add background point (red)
# 🖱️  Ctrl+Drag        : Draw bounding box
# ⌨️  'a' / 'Enter'    : Accept and save current mask
# ⌨️  'r'              : Reset current selection
# ⌨️  'u'              : Undo last saved mask
# ⌨️  's'              : Skip this image
# ⌨️  'q' / 'ESC'      : Next image / Finish
# ...
#
#   ✓ Saved mask 1 (area: 262645 pixels)
#   ✓ Saved mask 2 (area: 269110 pixels)
#   Undone - now 1 masks
#   Undone - now 0 masks
#   ✓ Saved mask 1 (area: 263072 pixels)
#   ✓ Saved mask 2 (area: 828727 pixels)
# ...

# %%
# !python sam_tool.py dataset/ output/ --mode interactive --export-yolo
# Out:
# Initializing SAM Tool...
# Using device: mps
# Using cached checkpoint: /Users/prudhvivuda/.cache/sam/sam_vit_b_01ec64.pth
# Loading SAM vit_b model...
# ✓ Model loaded successfully
#
# ...
# Starting interactive selection for 15 image(s)
# ...
#
#
# [1/15] Processing: bag.jpg
#
# ...
# INTERACTIVE SELECTION CONTROLS:
# --------------------------------------------------
# 🖱️  Left Click        : Add object point (green)
# 🖱️  Right Click       : Add background point (red)
# 🖱️  Ctrl+Drag        : Draw bounding box
# ⌨️  'a' / 'Enter'    : Accept and save current mask
# ⌨️  'r'              : Reset current selection
# ⌨️  'u'              : Undo last saved mask
# ⌨️  's'              : Skip this image
# ⌨️  'q' / 'ESC'      : Next image / Finish
# ...
#
#   ✓ Saved mask 1 (area: 3968905 pixels)
# ✓ Saved 1 masks
#
# [2/15] Processing: blender motor + air fryer + microwave.jpg
#
# ...
# INTERACTIVE SELECTION CONTROLS:
# --------------------------------------------------
# ...
