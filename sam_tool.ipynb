# %%
# Install SAM and dependencies
# !pip install segment-anything opencv-python matplotlib supervision
# !pip install pycocotools  # For COCO format export

# For text-based selection (optional)
# !pip install ultralytics  # For YOLO-World integration
# Out:
# Requirement already satisfied: segment-anything in ./venv/lib/python3.14/site-packages (1.0)
# Requirement already satisfied: opencv-python in ./venv/lib/python3.14/site-packages (4.12.0.88)
# Requirement already satisfied: matplotlib in ./venv/lib/python3.14/site-packages (3.10.7)
# Collecting supervision
#   Downloading supervision-0.26.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy<2.3.0,>=2 in ./venv/lib/python3.14/site-packages (from opencv-python) (2.2.6)
# Requirement already satisfied: contourpy>=1.0.1 in ./venv/lib/python3.14/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in ./venv/lib/python3.14/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./venv/lib/python3.14/site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./venv/lib/python3.14/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in ./venv/lib/python3.14/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in ./venv/lib/python3.14/site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in ./venv/lib/python3.14/site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in ./venv/lib/python3.14/site-packages (from matplotlib) (2.9.0.post0)
# Collecting scipy>=1.10.0 (from supervision)
#   Downloading scipy-1.16.2-cp314-cp314-macosx_14_0_arm64.whl.metadata (62 kB)
# Collecting pyyaml>=5.3 (from supervision)
#   Downloading pyyaml-6.0.3-cp314-cp314-macosx_11_0_arm64.whl.metadata (2.4 kB)
# Collecting defusedxml>=0.7.1 (from supervision)
#   Downloading defusedxml-0.7.1-py2.py3-none-any.whl.metadata (32 kB)
# Collecting requests>=2.26.0 (from supervision)
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: tqdm>=4.62.3 in ./venv/lib/python3.14/site-packages (from supervision) (4.67.1)
# Requirement already satisfied: six>=1.5 in ./venv/lib/python3.14/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Collecting charset_normalizer<4,>=2 (from requests>=2.26.0->supervision)
#   Using cached charset_normalizer-3.4.4-cp314-cp314-macosx_10_13_universal2.whl.metadata (37 kB)
# Collecting idna<4,>=2.5 (from requests>=2.26.0->supervision)
#   Using cached idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.26.0->supervision)
#   Using cached urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests>=2.26.0->supervision)
#   Using cached certifi-2025.10.5-py3-none-any.whl.metadata (2.5 kB)
# Downloading supervision-0.26.1-py3-none-any.whl (207 kB)
# Downloading defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Downloading pyyaml-6.0.3-cp314-cp314-macosx_11_0_arm64.whl (173 kB)
# Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# Using cached charset_normalizer-3.4.4-cp314-cp314-macosx_10_13_universal2.whl (207 kB)
# Using cached idna-3.11-py3-none-any.whl (71 kB)
# Using cached urllib3-2.5.0-py3-none-any.whl (129 kB)
# Using cached certifi-2025.10.5-py3-none-any.whl (163 kB)
# Downloading scipy-1.16.2-cp314-cp314-macosx_14_0_arm64.whl (20.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.9/20.9 MB 63.8 MB/s  0:00:00 eta 0:00:01
# Installing collected packages: urllib3, scipy, pyyaml, idna, defusedxml, charset_normalizer, certifi, requests, supervision
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9/9 [supervision] [charset_normalizer]
# Successfully installed certifi-2025.10.5 charset_normalizer-3.4.4 defusedxml-0.7.1 idna-3.11 pyyaml-6.0.3 requests-2.32.5 scipy-1.16.2 supervision-0.26.1 urllib3-2.5.0
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: pycocotools in ./venv/lib/python3.14/site-packages (2.0.10)
# Requirement already satisfied: numpy in ./venv/lib/python3.14/site-packages (from pycocotools) (2.2.6)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Collecting ultralytics
#   Downloading ultralytics-8.3.221-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: numpy>=1.23.0 in ./venv/lib/python3.14/site-packages (from ultralytics) (2.2.6)
# Requirement already satisfied: matplotlib>=3.3.0 in ./venv/lib/python3.14/site-packages (from ultralytics) (3.10.7)
# Requirement already satisfied: opencv-python>=4.6.0 in ./venv/lib/python3.14/site-packages (from ultralytics) (4.12.0.88)
# Requirement already satisfied: pillow>=7.1.2 in ./venv/lib/python3.14/site-packages (from ultralytics) (12.0.0)
# Requirement already satisfied: pyyaml>=5.3.1 in ./venv/lib/python3.14/site-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in ./venv/lib/python3.14/site-packages (from ultralytics) (2.32.5)
# Requirement already satisfied: scipy>=1.4.1 in ./venv/lib/python3.14/site-packages (from ultralytics) (1.16.2)
# Requirement already satisfied: torch>=1.8.0 in ./venv/lib/python3.14/site-packages (from ultralytics) (2.9.0)
# Requirement already satisfied: torchvision>=0.9.0 in ./venv/lib/python3.14/site-packages (from ultralytics) (0.24.0)
# Requirement already satisfied: psutil in ./venv/lib/python3.14/site-packages (from ultralytics) (7.1.2)
# Collecting polars (from ultralytics)
#   Downloading polars-1.34.0-py3-none-any.whl.metadata (10 kB)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.17-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: contourpy>=1.0.1 in ./venv/lib/python3.14/site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in ./venv/lib/python3.14/site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./venv/lib/python3.14/site-packages (from matplotlib>=3.3.0->ultralytics) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./venv/lib/python3.14/site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in ./venv/lib/python3.14/site-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=3 in ./venv/lib/python3.14/site-packages (from matplotlib>=3.3.0->ultralytics) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in ./venv/lib/python3.14/site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in ./venv/lib/python3.14/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./venv/lib/python3.14/site-packages (from requests>=2.23.0->ultralytics) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in ./venv/lib/python3.14/site-packages (from requests>=2.23.0->ultralytics) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./venv/lib/python3.14/site-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./venv/lib/python3.14/site-packages (from requests>=2.23.0->ultralytics) (2025.10.5)
# Requirement already satisfied: filelock in ./venv/lib/python3.14/site-packages (from torch>=1.8.0->ultralytics) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in ./venv/lib/python3.14/site-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools in ./venv/lib/python3.14/site-packages (from torch>=1.8.0->ultralytics) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in ./venv/lib/python3.14/site-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in ./venv/lib/python3.14/site-packages (from torch>=1.8.0->ultralytics) (3.5)
# Requirement already satisfied: jinja2 in ./venv/lib/python3.14/site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in ./venv/lib/python3.14/site-packages (from torch>=1.8.0->ultralytics) (2025.9.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./venv/lib/python3.14/site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./venv/lib/python3.14/site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)
# Collecting polars-runtime-32==1.34.0 (from polars->ultralytics)
#   Downloading polars_runtime_32-1.34.0-cp39-abi3-macosx_11_0_arm64.whl.metadata (1.5 kB)
# Downloading ultralytics-8.3.221-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 16.6 MB/s  0:00:00
# Downloading ultralytics_thop-2.0.17-py3-none-any.whl (28 kB)
# Downloading polars-1.34.0-py3-none-any.whl (772 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 772.7/772.7 kB 22.5 MB/s  0:00:00
# Downloading polars_runtime_32-1.34.0-cp39-abi3-macosx_11_0_arm64.whl (36.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.0/36.0 MB 56.4 MB/s  0:00:00m0:00:0100:01
# Installing collected packages: polars-runtime-32, polars, ultralytics-thop, ultralytics
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [ultralytics] [ultralytics]
# Successfully installed polars-1.34.0 polars-runtime-32-1.34.0 ultralytics-8.3.221 ultralytics-thop-2.0.17
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
# !python sam_tool.py dataset/ output/ --mode interactive --device mps --export-yolo
# Out:
# Matplotlib is building the font cache; this may take a moment.
# Initializing SAM Tool...
# Using device: mps
# Downloading SAM vit_b checkpoint...
# This is a one-time download (~375MB)
# Progress: 100.0%
# ✓ Downloaded to /Users/pvuda/.cache/sam/sam_vit_b_01ec64.pth
# Loading SAM vit_b model...
# ✓ Model loaded successfully
#
# ============================================================
# Starting interactive selection for 15 image(s)
# ============================================================
#
#
# [1/15] Processing: bag.jpg
#
# ==================================================
# INTERACTIVE SELECTION CONTROLS:
# --------------------------------------------------
# 🖱️  Left Click        : Add object point (green)
# 🖱️  Right Click       : Add background point (red)
# 🖱️  Ctrl+Drag        : Draw bounding box
# ⌨️  'a' / 'Enter'    : Accept and save current mask
# ⌨️  'r'              : Reset current selection
# ⌨️  'u'              : Undo last saved mask
# ⌨️  's'              : Skip this image
# ⌨️  'q' / 'ESC'      : Next image / Finish
# ==================================================
#
#   ✓ Saved mask 1 (area: 3954968 pixels)
# ✓ Saved 1 masks
#
# [2/15] Processing: blender motor + air fryer + microwave.jpg
#
# ==================================================
# INTERACTIVE SELECTION CONTROLS:
# --------------------------------------------------
# 🖱️  Left Click        : Add object point (green)
# 🖱️  Right Click       : Add background point (red)
# 🖱️  Ctrl+Drag        : Draw bounding box
# ⌨️  'a' / 'Enter'    : Accept and save current mask
# ⌨️  'r'              : Reset current selection
# ⌨️  'u'              : Undo last saved mask
# ⌨️  's'              : Skip this image
# ⌨️  'q' / 'ESC'      : Next image / Finish
# ==================================================
#
#   ✓ Saved mask 1 (area: 245495 pixels)
#   ✓ Saved mask 2 (area: 832792 pixels)
#   ✓ Saved mask 3 (area: 1090406 pixels)
# ✓ Saved 3 masks
#
# [3/15] Processing: blender motor + air fryer.jpg
#
# ==================================================
# INTERACTIVE SELECTION CONTROLS:
# --------------------------------------------------
# 🖱️  Left Click        : Add object point (green)
# 🖱️  Right Click       : Add background point (red)
# 🖱️  Ctrl+Drag        : Draw bounding box
# ⌨️  'a' / 'Enter'    : Accept and save current mask
# ⌨️  'r'              : Reset current selection
# ⌨️  'u'              : Undo last saved mask
# ⌨️  's'              : Skip this image
# ⌨️  'q' / 'ESC'      : Next image / Finish
# ==================================================
#
#   ✓ Saved mask 1 (area: 467724 pixels)
# ✓ Saved 1 masks
#
# [4/15] Processing: dish washer.jpg
#
# ==================================================
# INTERACTIVE SELECTION CONTROLS:
# --------------------------------------------------
# 🖱️  Left Click        : Add object point (green)
# 🖱️  Right Click       : Add background point (red)
# 🖱️  Ctrl+Drag        : Draw bounding box
# ⌨️  'a' / 'Enter'    : Accept and save current mask
# ⌨️  'r'              : Reset current selection
# ⌨️  'u'              : Undo last saved mask
# ⌨️  's'              : Skip this image
# ⌨️  'q' / 'ESC'      : Next image / Finish
# ==================================================
#
#   ✓ Saved mask 1 (area: 2327977 pixels)
# ✓ Saved 1 masks
#
# [5/15] Processing: dryer + washer.jpg
#
# ==================================================
# INTERACTIVE SELECTION CONTROLS:
# --------------------------------------------------
# 🖱️  Left Click        : Add object point (green)
# 🖱️  Right Click       : Add background point (red)
# 🖱️  Ctrl+Drag        : Draw bounding box
# ⌨️  'a' / 'Enter'    : Accept and save current mask
# ⌨️  'r'              : Reset current selection
# ⌨️  'u'              : Undo last saved mask
# ⌨️  's'              : Skip this image
# ⌨️  'q' / 'ESC'      : Next image / Finish
# ==================================================
#
#   ✓ Saved mask 1 (area: 3359415 pixels)
# ✓ Saved 1 masks
#
# [6/15] Processing: fan.jpg
#
# ==================================================
# INTERACTIVE SELECTION CONTROLS:
# --------------------------------------------------
# 🖱️  Left Click        : Add object point (green)
# 🖱️  Right Click       : Add background point (red)
# 🖱️  Ctrl+Drag        : Draw bounding box
# ⌨️  'a' / 'Enter'    : Accept and save current mask
# ⌨️  'r'              : Reset current selection
# ⌨️  'u'              : Undo last saved mask
# ⌨️  's'              : Skip this image
# ⌨️  'q' / 'ESC'      : Next image / Finish
# ==================================================
#
#   ✓ Saved mask 1 (area: 1623515 pixels)
# ✓ Saved 1 masks
#
# [7/15] Processing: fridge.jpg
#
# ==================================================
# INTERACTIVE SELECTION CONTROLS:
# --------------------------------------------------
# 🖱️  Left Click        : Add object point (green)
# 🖱️  Right Click       : Add background point (red)
# 🖱️  Ctrl+Drag        : Draw bounding box
# ⌨️  'a' / 'Enter'    : Accept and save current mask
# ⌨️  'r'              : Reset current selection
# ⌨️  'u'              : Undo last saved mask
# ⌨️  's'              : Skip this image
# ⌨️  'q' / 'ESC'      : Next image / Finish
# ==================================================
#
#   ✓ Saved mask 1 (area: 2283221 pixels)
# ✓ Saved 1 masks
#
# [8/15] Processing: heater.jpg
#
# ==================================================
# INTERACTIVE SELECTION CONTROLS:
# --------------------------------------------------
# 🖱️  Left Click        : Add object point (green)
# 🖱️  Right Click       : Add background point (red)
# 🖱️  Ctrl+Drag        : Draw bounding box
# ⌨️  'a' / 'Enter'    : Accept and save current mask
# ⌨️  'r'              : Reset current selection
# ⌨️  'u'              : Undo last saved mask
# ⌨️  's'              : Skip this image
# ⌨️  'q' / 'ESC'      : Next image / Finish
# ==================================================
#
#   ✓ Saved mask 1 (area: 971763 pixels)
# ✓ Saved 1 masks
#
# [9/15] Processing: instant pot.jpg
#
# ==================================================
# INTERACTIVE SELECTION CONTROLS:
# --------------------------------------------------
# 🖱️  Left Click        : Add object point (green)
# 🖱️  Right Click       : Add background point (red)
# 🖱️  Ctrl+Drag        : Draw bounding box
# ⌨️  'a' / 'Enter'    : Accept and save current mask
# ⌨️  'r'              : Reset current selection
# ⌨️  'u'              : Undo last saved mask
# ⌨️  's'              : Skip this image
# ⌨️  'q' / 'ESC'      : Next image / Finish
# ==================================================
#
#   ✓ Saved mask 1 (area: 1595429 pixels)
# ✓ Saved 1 masks
#
# [10/15] Processing: kitchen weight scale.jpg
#
# ==================================================
# INTERACTIVE SELECTION CONTROLS:
# --------------------------------------------------
# 🖱️  Left Click        : Add object point (green)
# 🖱️  Right Click       : Add background point (red)
# 🖱️  Ctrl+Drag        : Draw bounding box
# ⌨️  'a' / 'Enter'    : Accept and save current mask
# ⌨️  'r'              : Reset current selection
# ⌨️  'u'              : Undo last saved mask
# ⌨️  's'              : Skip this image
# ⌨️  'q' / 'ESC'      : Next image / Finish
# ==================================================
#
#   ✓ Saved mask 1 (area: 892594 pixels)
# ✓ Saved 1 masks
#
# [11/15] Processing: laptop.jpg
#
# ==================================================
# INTERACTIVE SELECTION CONTROLS:
# --------------------------------------------------
# 🖱️  Left Click        : Add object point (green)
# 🖱️  Right Click       : Add background point (red)
# 🖱️  Ctrl+Drag        : Draw bounding box
# ⌨️  'a' / 'Enter'    : Accept and save current mask
# ⌨️  'r'              : Reset current selection
# ⌨️  'u'              : Undo last saved mask
# ⌨️  's'              : Skip this image
# ⌨️  'q' / 'ESC'      : Next image / Finish
# ==================================================
#
#   ✓ Saved mask 1 (area: 3637894 pixels)
# ✓ Saved 1 masks
#
# [12/15] Processing: monitor.jpg
#
# ==================================================
# INTERACTIVE SELECTION CONTROLS:
# --------------------------------------------------
# 🖱️  Left Click        : Add object point (green)
# 🖱️  Right Click       : Add background point (red)
# 🖱️  Ctrl+Drag        : Draw bounding box
# ⌨️  'a' / 'Enter'    : Accept and save current mask
# ⌨️  'r'              : Reset current selection
# ⌨️  'u'              : Undo last saved mask
# ⌨️  's'              : Skip this image
# ⌨️  'q' / 'ESC'      : Next image / Finish
# ==================================================
#
#   ✓ Saved mask 1 (area: 2736294 pixels)
# ✓ Saved 1 masks
#
# [13/15] Processing: tv.jpg
#
# ==================================================
# INTERACTIVE SELECTION CONTROLS:
# --------------------------------------------------
# 🖱️  Left Click        : Add object point (green)
# 🖱️  Right Click       : Add background point (red)
# 🖱️  Ctrl+Drag        : Draw bounding box
# ⌨️  'a' / 'Enter'    : Accept and save current mask
# ⌨️  'r'              : Reset current selection
# ⌨️  'u'              : Undo last saved mask
# ⌨️  's'              : Skip this image
# ⌨️  'q' / 'ESC'      : Next image / Finish
# ==================================================
#
#   ✓ Saved mask 1 (area: 1555275 pixels)
# ✓ Saved 1 masks
#
# [14/15] Processing: vaccum cleaner.jpg
#
# ==================================================
# INTERACTIVE SELECTION CONTROLS:
# --------------------------------------------------
# 🖱️  Left Click        : Add object point (green)
# 🖱️  Right Click       : Add background point (red)
# 🖱️  Ctrl+Drag        : Draw bounding box
# ⌨️  'a' / 'Enter'    : Accept and save current mask
# ⌨️  'r'              : Reset current selection
# ⌨️  'u'              : Undo last saved mask
# ⌨️  's'              : Skip this image
# ⌨️  'q' / 'ESC'      : Next image / Finish
# ==================================================
#
#   ✓ Saved mask 1 (area: 1578091 pixels)
# ✓ Saved 1 masks
#
# [15/15] Processing: window ac.jpg
#
# ==================================================
# INTERACTIVE SELECTION CONTROLS:
# --------------------------------------------------
# 🖱️  Left Click        : Add object point (green)
# 🖱️  Right Click       : Add background point (red)
# 🖱️  Ctrl+Drag        : Draw bounding box
# ⌨️  'a' / 'Enter'    : Accept and save current mask
# ⌨️  'r'              : Reset current selection
# ⌨️  'u'              : Undo last saved mask
# ⌨️  's'              : Skip this image
# ⌨️  'q' / 'ESC'      : Next image / Finish
# ==================================================
#
#   ✓ Saved mask 1 (area: 2474108 pixels)
# ✓ Saved 1 masks
#
# ============================================================
# ✅ Interactive selection complete!
# 📊 Total masks selected: 17
# 📁 Output saved to: output
# ============================================================
#
#
# Exporting to YOLO format...
#
# ✅ Exported 17 labels to YOLO format
# 📁 Labels saved to: output/yolo_labels/labels
# 📝 Classes file: output/yolo_labels/classes.txt
# 📊 Number of classes: 3
